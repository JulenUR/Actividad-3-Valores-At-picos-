# %% [markdown]
# <a href="https://colab.research.google.com/github/JulenUR/Actividad-3-Valores-At-picos-/blob/main/Actividad_3_Valores_At%C3%ADpicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Julen Ugartechea Repetto - A01735646
#
# ### Actividad 3 (Valores Atípicos)

# %%
#Importamos las librerías pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-df6dbd13-7fc7-4f54-9213-3c3cdfd594c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df6dbd13-7fc7-4f54-9213-3c3cdfd594c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Carga desde un archivo .xlsx sin índice
data = pd.read_csv('A01735646_ACT2_Valores_Nulos.csv')
data
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 25 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           65 non-null     int64
#  1   indice_tiempo                        65 non-null     object
#  2   ventas_precios_corrientes            65 non-null     float64
#  3   ventas_precios_constantes            65 non-null     float64
#  4   ventas_totales_canal_venta           65 non-null     float64
#  5   salon_ventas                         65 non-null     float64
#  6   canales_on_line                      65 non-null     float64
#  7   ventas_totales_medio_pago            65 non-null     float64
#  8   efectivo                             65 non-null     float64
#  9   tarjetas_debito                      65 non-null     float64
#  10  tarjetas_credito                     65 non-null     float64
# ...

# %%
#Corroboramos valores nulos
valores_nulos = data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           0
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %% [markdown]
# # COLUMNA 1

# %%
# COLUMNA 1: ventas_precios_corrientes
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data['ventas_precios_corrientes'])
plt.title('Outliers de ventas_precios_corrientes')
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["ventas_precios_corrientes"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos outliers
outliers_col1 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col1
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                 81140696.22   76413721.76
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457                81140696.22  24935747.29      22143208.63
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                          2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col1 = data[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
clean_col1
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col1["ventas_precios_corrientes"])
plt.title("Outliers de ventas_precios_corrientes")
plt.show()

# %% [markdown]
# # COLUMNA 2

# %%
# COLUMNA 2: ventas_precios_constantes
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["ventas_precios_constantes"])
plt.title("Outliers de ventas_precios_constantes")
plt.show()

# %%
#Métodos aplicando desviación estandar. Encuentro los valores extremos
y = data["ventas_precios_constantes"]
Limite_Superior = y.mean() + 3*y.std()
Limite_Inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 40022.90598479884
# Limite inferior permitido 12104.484784431932

# %%
#Encontramos outliers
outliers_col2 = data[(y > Limite_Superior) | (y < Limite_Inferior)]
outliers_col2
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 42          42    01/07/2020                   211140.7
# 60          60    01/01/2022                   154517.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 42                    50791.4                8.114070e+07  7.641372e+07
# 60                    45463.4                1.545171e+08  1.496976e+08
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 42      4726974.457               8.114070e+07  24935747.29      22143208.63
# 60      4819479.554               1.545171e+08  46962602.22      46053650.13
#
#     ...      almacen    panaderia       lacteos        carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8.463266e+06
# 60  ...  37505172.62  4860317.680  1.610477e+07  1.740849e+07
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                    5.189425e+05
# ...

# %%
#Obtenemos datos limpios
clean_col2 = data[(y <= Limite_Superior) & (y >= Limite_Inferior)]
clean_col2
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 4))
plt.boxplot(clean_col2["ventas_precios_constantes"])
plt.title("Outliers de ventas_precios_constantes")
plt.show ()

# %% [markdown]
# # COLUMNA 3

# %%
# COLUMNA 3: salon_ventas
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show()

# %%
#Método aplicando desviación estandar. Encuentro los valores extremos
y = data['salon_ventas']
Limite_superior = y.mean() + 3*y.std()
Limite_inferior = y.mean() - 3*y.std()
print('Limite superior permitido', Limite_superior)
print('Limite inferior permitido', Limite_inferior)
# Out:
# Limite superior permitido 197606560.24354827
# Limite inferior permitido -45934387.42083639

# %%
#Encontramos outliers
outliers_col3 = data[(y > Limite_Superior) | (y < Limite_Inferior)]
outliers_col3
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
clean_col3 = data[(y <= Limite_Superior) & (y >= Limite_Inferior)]
clean_col3
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 4))
plt.boxplot(clean_col3["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show()

# %% [markdown]
# # COLUMNA 4

# %%
# COLUMNA 4: tarjetas_debito
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["tarjetas_debito"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 51933510.0585
# Limite inferior permitido -15937937.1375

# %%
#Encontramos outliers
outliers_col4 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col4
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col4 = data[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
clean_col4
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col4["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show()

# %% [markdown]
# # COLUMNA 5

# %%
# COLUMNA 5: tarjetas_credito
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show()

# %%
#Métodos aplicando desviación estandar. Encuentro los valores extremos
y = data["tarjetas_credito"]
Limite_Superior = y.mean() + 3*y.std()
Limite_Inferior = y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 74177760.0031438
# Limite inferior permitido -21391552.06289764

# %%
#Encontramos outliers
outliers_col5 = data[(y > Limite_Superior) | (y < Limite_Inferior)]
outliers_col5
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col5 = data[(y <= Limite_Superior) & (y >= Limite_Inferior)]
clean_col5
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col5["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show()

# %% [markdown]
# # COLUMNA 6

# %%
# COLUMNA 6: subtotal_ventas_alimentos_bebidas
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["subtotal_ventas_alimentos_bebidas"])
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["subtotal_ventas_alimentos_bebidas"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 135934765.575
# Limite inferior permitido -47434646.705000006

# %%
#Encontramos outliers
outliers_col6 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col6
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col6 = data[(y <= Limite_Superior_iqr) & (y>=Limite_Inferior_iqr)]
clean_col6
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col6["subtotal_ventas_alimentos_bebidas"])
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show()

# %% [markdown]
# # COLUMNA 7

# %%
# COLUMNA 7: bebidas
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["bebidas"])
plt.title("Outliers de bebidas")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["bebidas"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 23788205.776499998
# Limite inferior permitido -7302449.5474999985

# %%
#Encontramos outliers
outliers_col7 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col7
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                          4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col7 = data[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
clean_col7
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot (clean_col7["bebidas"])
plt.title("Outliers de bebidas")
plt.show()

# %% [markdown]
# # COLUMNA 8

# %%
# COLUMNA 8: panaderia
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot (data["panaderia"])
plt.title("Outliers de panaderia")
plt.show()

# %%
#Métodos aplicando desviación estandar. Encuentro los valores extremos
y=data["panaderia"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 6984940.292889729
# Limite inferior permitido -1843701.2237666529

# %%
#Encontramos outliers
outliers_col8 = data[(y > Limite_Superior) | (y < Limite_Inferior)]
outliers_col8
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col8 = data[(y <= Limite_Superior) & (y >= Limite_Inferior)]
clean_col8
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize =(5, 4))
plt.boxplot(clean_col8["panaderia"])
plt.title("Outliers de panaderia")
plt.show()

# %% [markdown]
# # COLUMNA 9

# %%
# COLUMNA 9: lacteos
#Diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(data["lacteos"])
plt.title("Outliers de lacteos")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["lacteos"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 19940661.0455
# Limite inferior permitido -5569362.3025

# %%
#Encontramos outliers
outliers_col9 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col9
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 64                    23234.2                 179639238.6   175358487.5
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 64      4280751.113                179639238.6  52738110.62      49886787.86
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria  indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                          5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 25 columns]

# %%
#Obtenemos datos limpios
clean_col9 = data[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
clean_col9
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col9["lacteos"])
plt.title("Outliers de lacteos")
plt.show()

# %% [markdown]
# # COLUMNA 10

# %%
# COLUMNA 10: otros
#Diagrama de caja o bigote
fig = plt. figure(figsize = (5, 4))
plt.boxplot(data["otros"])
plt.title("Outliers de otros")
plt.show()

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y = data["otros"]

percentile25 = y.quantile(0.25)
percentile75 = y.quantile(0.75)
iqr = percentile75 - percentile25

Limite_Superior_iqr = percentile75 + 1.5*iqr
Limite_Inferior_iqr = percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 13169100.024999999
# Limite inferior permitido -2599893.999

# %%
#Encontramos outliers
outliers_col10 = data[(y > Limite_Superior_iqr) | (y < Limite_Inferior_iqr)]
outliers_col10
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 59          59    01/12/2021                   183983.2
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 59                    31595.7                 183983151.9   178866721.2
# 60                    45463.4                 154517094.2   149697614.6
# 61                    23802.1                 152202573.4   148406529.3
#
#     canales_on_line  ventas_totales_medio_pago     efectivo  tarjetas_debito  \
# 59      5116430.634                183983151.9  56640033.15      55432191.37
# 60      4819479.554                154517094.2  46962602.22      46053650.13
# 61      3796044.076                152202573.4  46290956.21      45283575.25
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
# ...

# %%
#Obtenemos datos limpios
clean_col10 = data[(y <= Limite_Superior_iqr) & (y >= Limite_Inferior_iqr)]
clean_col10
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 57          57    01/10/2021                   140487.5
# 58          58    01/11/2021                   141702.0
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Realizamos diagrama de caja o bigote
fig = plt.figure(figsize = (5, 4))
plt.boxplot(clean_col10["otros"])
plt.title("Outliers de otros")
plt.show()

# %%
clean_col1.to_csv('clean_col1.csv')
clean_col2.to_csv('clean_col2.csv')
clean_col3.to_csv('clean_col3.csv')
clean_col4.to_csv('clean_col4.csv')
clean_col5.to_csv('clean_col5.csv')
clean_col6.to_csv('clean_col6.csv')
clean_col7.to_csv('clean_col7.csv')
clean_col8.to_csv('clean_col8.csv')
clean_col9.to_csv('clean_col9.csv')
clean_col10.to_csv('clean_col10.csv')

# %%
#Descargar archivo filtrado en csv
from google.colab import files

files.download('clean_col1.csv')
files.download('clean_col2.csv')
files.download('clean_col3.csv')
files.download('clean_col4.csv')
files.download('clean_col5.csv')
files.download('clean_col6.csv')
files.download('clean_col7.csv')
files.download('clean_col8.csv')
files.download('clean_col9.csv')
files.download('clean_col10.csv')
